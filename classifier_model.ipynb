# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2023-09-09 02:52:19.320268: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 02:52:20.059053: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/goru/.conda/envs/tf/lib/python3.7/site-packages/nvidia/cudnn/lib:/home/goru/.conda/envs/tf/lib/:
# 2023-09-09 02:52:20.059109: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/goru/.conda/envs/tf/lib/python3.7/site-packages/nvidia/cudnn/lib:/home/goru/.conda/envs/tf/lib/:
# 2023-09-09 02:52:20.059116: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df =pd.read_csv("Data/spam.csv",encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
 df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'Target','v2':'Text'},inplace = True)

# %%
df.head()
# Out:
#   Target                                               Text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
# !pip install -U scikit-learn scipy matplotlib
# Out:
# Requirement already satisfied: scikit-learn in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (1.0.2)
# Requirement already satisfied: scipy in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (1.7.3)
# Requirement already satisfied: matplotlib in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (3.5.3)
# Requirement already satisfied: numpy>=1.14.6 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: typing-extensions in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.7.1)
# Requirement already satisfied: six>=1.5 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df['Target'] = encoder.fit_transform(df['Target'])

# %%
df.head()
# Out:
#    Target                                               Text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Target  5572 non-null   int64
#  1   Text    5572 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 87.2+ KB

# %%
df.isnull().sum()
# Out:
# Target    0
# Text      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5567    False
# 5568    False
# 5569    False
# 5570    False
# 5571    False
# Length: 5572, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %%
df['Target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: Target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['Target'].value_counts(),labels= ['ham','spam'],autopct="%0.2f")
plt.show()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/goru/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: joblib in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: tqdm in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: click in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: importlib-metadata in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from click->nltk) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.7.1)

# %%
df['Number of chars']=df['Text'].apply(len)

# %%
df.head()
# Out:
#    Target                                               Text  Number of chars
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61

# %%
df['Number of Words']=df['Text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    Target                                               Text  Number of chars  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    Number of Words
# 0               24
# 1                8
# 2               37
# 3               13
# 4               15

# %%
df['Number of Sentence']= df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    Target                                               Text  Number of chars  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    Number of Words  Number of Sentence
# 0               24                   2
# 1                8                   2
# 2               37                   2
# 3               13                   1
# 4               15                   1

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from seaborn) (1.21.6)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: typing_extensions in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from seaborn) (4.7.1)
# Requirement already satisfied: pandas>=0.25 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: pytz>=2017.3 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# # Droping num of words,sentence and keeping num of chars because there is too  much  corelation

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string
ps= PorterStemmer()

# %%
def text_transform(text):
    text= text.lower()
    text = nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
        
    
    return " ".join(y)

# %%
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/goru/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text_transform('Hello Sir. I am up and running.How may I help you?')
# Out:
# 'hello sir may help'

# %%
df['Transformed Text']=df['Text'].apply(text_transform)

# %%
df.head()
# Out:
#    Target                                               Text  Number of chars  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    Number of Words  Number of Sentence  \
# 0               24                   2
# 1                8                   2
# 2               37                   2
# 3               13                   1
# 4               15                   1
#
#                                     Transformed Text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: typing-extensions in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->wordcloud) (4.7.1)
# Requirement already satisfied: six>=1.5 in /home/goru/.conda/envs/tf/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='black')

# %%
spam_wc = wc.generate(df[df['Target']==1]['Transformed Text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['Target']==0]['Transformed Text'].str.cat(sep=" "))

# %%
plt.imshow(ham_wc)

# %%
spam_corpus=[]
for msg in df[df['Target']==1]['Transformed Text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
# from collections import Counter
# sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
# plt.xticks(rotation='vertical')
# plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X= tfidf.fit_transform(df['Transformed Text']).toarray()

# %%
y= df['Target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
gnb = GaussianNB()
bnb= BernoulliNB()
mnb= MultinomialNB()

# %%
gnb.fit(X_train,y_train)
y_pred1= gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2= mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3= bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
#mnb gives the best precision score with  TFidf--> thats why using mnb

# %%
import pickle
pickle.dump(tfidf,open('vectoriser.pkl', 'wb'))
pickle.dump(mnb,open('model.pkl', 'wb'))
